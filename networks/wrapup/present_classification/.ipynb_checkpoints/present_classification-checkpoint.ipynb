# %%
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
pd.set_option("display.max_columns", 50)
sys.path.insert(0,'/home/oem/Projects/Kylearn')
from Models.Mean_Teacher.mean_teacher_dataset import Mean_Teacher_dataset

# %% [markdown]
# ## Functions for drawing confusion matrix

# %%
import matplotlib.pyplot as pyplot
import numpy as np
import pandas as pd
import seaborn as sb
import math
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import classification_report

pyplot.rcParams['savefig.dpi'] = 300  # pixel
pyplot.rcParams['figure.dpi'] = 300  # resolution
pyplot.rcParams["figure.figsize"] = [10,8] # figure size

def draw_confusion_matrix(cm, labels, plt = pyplot, x_rotation=90, y_rotation=0, font_size=0.33, precision=False):


    if (precision):
        '''flip and rotate the confusion metrix'''
        labels = labels[::-1]
        cm = np.rot90(np.flip(cm, axis=0))

    cm_sum = np.sum(cm, axis=1, keepdims=True)

    cm_perc = cm / cm_sum.astype(float) * 100

    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif (c == 0):
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)

    if (precision):
        cm.columns.name = 'True Label'
        cm.index.name = 'Predict Label'
    else:
        cm.index.name = 'True Label'
        cm.columns.name = 'Predict Label'

    sb.set(font_scale=font_size)

    sb.heatmap(cm, annot=annot, fmt='', cmap='Blues')
    plt.xticks(rotation=x_rotation)
    plt.yticks(rotation=y_rotation)

    plt.show()

# get confusion matrix and accuracy, plot classification report
def metrics_multi(y_pred, y_test, labels):
    cm = confusion_matrix(np.array(y_test).flatten(), np.array(y_pred).flatten())
    print(classification_report(np.array(y_test).flatten(), np.array(y_pred).flatten()))
    acc = accuracy_score(y_test, y_pred)
    return cm, acc

# get metrics for binary classification
def metrics_binary(y_pred, threshold, y_test):
    y_pred_copy = y_pred.copy()
    y_pred_copy[y_pred_copy >= threshold] = 1
    y_pred_copy[y_pred_copy < threshold] = 0
    cm = confusion_matrix(y_test, y_pred_copy)
    tp = cm[1, 1]
    tn = cm[0, 0]
    fp = cm[0, 1]
    fn = cm[1, 0]
    fpr = fp / (fp + tn)
    accuracy = (tp + tn) / (np.sum(cm))
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    print('accuracy: ' + str(accuracy) + '\n')
    print('precision: ' + str(precision) + '\n')
    print('recall: ' + str(recall) + '\n')
    print('false positive rate: ' + str(fpr) + '\n')
    return cm, fpr, accuracy, precision, recall

# %% [markdown]
# ## Functions for drawing ROC

# %%
# Functions for drawing ROC
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve

def auc_roc(y_pred, y_test):
    auc = roc_auc_score(y_true=y_test, y_score=y_pred)
    fprs, tprs, thresholds = roc_curve(y_true=y_test, y_score=y_pred)
    return auc, fprs, tprs, thresholds

import matplotlib.pyplot as pyplot
pyplot.rcParams['savefig.dpi'] = 300  # pixel
pyplot.rcParams['figure.dpi'] = 300  # resolution
pyplot.rcParams["figure.figsize"] = [4,3] # figure size

def plot_roc_curve(fprs, tprs, auc, x_axis = 1, plt = pyplot):

    plt.plot(fprs, tprs, color="darkorange", label='ROC curve (area = %0.3f)' % auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, x_axis])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Functions for visualize attention matrix

# %%
def visualize_input_attention(matrix, dev_list, pm_list):
    attn_matrix = pd.DataFrame(data=matrix, index=dev_list, columns=pm_list)
    attn_matrix[attn_matrix == 1] = 0
    attn_matrix[attn_matrix == 0] = 'x'
    return attn_matrix

def visualize_output_attention(matrix, dev_list, alarm_list):
    attn_matrix = pd.DataFrame(data=matrix, index=dev_list, columns=alarm_list)
    return attn_matrix

# %% [markdown]
# ## Define lists

# %%
alarm_list = ['Excessive Error Ratio', 'Frequency Out Of Range', 'GCC0 Link Failure',
              'Gauge Threshold Crossing Alert Summary', 'Link Down', 'Local Fault',
              'Loss Of Clock', 'Loss Of Frame', 'Loss Of Signal', 'OSC OSPF Adjacency Loss',
              'OTU Signal Degrade', 'Rx Power Out Of Range']
dev_list = ['AMP', 'ETH10G', 'ETHN', 'ETTP', 'OC192', 'OPTMON', 'OSC', 'OTM', 'OTM2', 'OTUTTP', 'PTP']

pm_list = ['BBE-RS',
            'CV-OTU', 'CV-S',
            'DROPGAINAVG-OTS', 'DROPGAINMAX-OTS_DROPGAINMIN-OTS_-',
            'E-CV', 'E-ES', 'E-INFRAMESERR_E-INFRAMES_/', 'E-OUTFRAMESERR_E-OUTFRAMES_/',
            'E-UAS', 'ES-OTU', 'ES-RS', 'ES-S',
            'OCH-OPRAVG', 'OCH-OPRMAX_OCH-OPRMIN_-', 'OCH-SPANLOSSAVG', 'OCH-SPANLOSSMAX_OCH-SPANLOSSMIN_-',
            'OPINAVG-OTS', 'OPINMAX-OTS_OPINMIN-OTS_-',
            'OPOUTAVG-OTS', 'OPOUTAVG-OTS_OPINAVG-OTS_-', 'OPOUTMAX-OTS_OPOUTMIN-OTS_-',
            'OPRAVG-OCH', 'OPRAVG-OTS', 'OPRMAX-OCH_OPRMIN-OCH_-', 'OPRMAX-OTS_OPRMIN-OTS_-',
            'OPTAVG-OCH', 'OPTAVG-OTS', 'OPTMAX-OCH_OPTMIN-OCH_-', 'OPTMAX-OTS_OPTMIN-OTS_-',
            'ORLAVG-OTS', 'ORLMIN-OTS', 'OTU-CV', 'OTU-ES', 'OTU-QAVG', 'OTU-QSTDEV',
            'PCS-CV', 'PCS-ES', 'PCS-UAS',
            'QAVG-OTU', 'QSTDEV-OTU',
            'RS-BBE', 'RS-ES',
            'S-CV', 'S-ES']

# %% [markdown]
# ## Restore model and rebuild the graph

# %%
# Restore model
number = 50000
sess = tf.Session()
saver = tf.train.import_meta_graph('models/-%s.meta'%str(number))
saver.restore(sess=sess, save_path='models/-%s'%str(number))
graph = tf.get_default_graph()
# Out:
# INFO:tensorflow:Restoring parameters from models/-50000

# %%
# Get tensors
input_x = graph.get_tensor_by_name('input/features:0')
input_dev = graph.get_tensor_by_name('input/dev_type:0')
is_training = graph.get_tensor_by_name('input/is_training:0')
output_proba = graph.get_tensor_by_name('error/Sigmoid:0')
output_prediction = graph.get_tensor_by_name('error/ArgMax:0')
attention_matrix = graph.get_tensor_by_name('scaling_attention/LeakyRelu:0') 
attention_matrix_output = graph.get_tensor_by_name('bias_attention/LeakyRelu:0')

# %% [markdown]
# ## Load data

# %%
# use dataset or just load npy file
dataset = Mean_Teacher_dataset(feature_path='data/X',
                               dev_path= 'data/dev',
                               label_path='data/y',
                               unlabeled_feature_path='data/X_un',
                               unlabeled_dev_path='data/dev_un'
                               )

# %% [markdown]
# ## Output prediction, accuracy, confusion matrix and draw

# %%
# Output prediction
prediction = sess.run(output_prediction, feed_dict={input_x: dataset.test_set['x'],
                                           input_dev: dataset.test_set['dev'],
                                           is_training: False})

cm, accuracy = metrics_multi(
    y_pred=prediction, y_test=dataset.test_set['y'], labels=alarm_list)

print('accuracy: %f'%accuracy)
draw_confusion_matrix(cm, alarm_list, precision=False, plt=pyplot, font_size = 0.3)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.09      0.17        97
#            1       0.98      1.00      0.99       253
#            2       0.38      0.12      0.18        26
#            3       0.93      0.93      0.93        15
#            4       1.00      1.00      1.00        16
#            5       0.67      0.98      0.80       570
#            6       0.29      0.41      0.34        17
#            7       0.57      0.15      0.23       234
#            8       0.71      0.73      0.72       158
#            9       1.00      1.00      1.00        21
#           10       0.40      0.32      0.35        19
#           11       0.91      0.91      0.91        43
#
#    micro avg       0.73      0.73      0.73      1469
#    macro avg       0.74      0.64      0.63      1469
# weighted avg       0.74      0.73      0.68      1469
#
# accuracy: 0.733152

# %% [markdown]
# ## Output probabilities for each class, and draw ROC respectively

# %%
# Output probability
proba = sess.run(output_proba, feed_dict={input_x: dataset.test_set['x'],
                                           input_dev: dataset.test_set['dev'],
                                           is_training: False})
proba[0:3]
# Out:
# array([[9.9249375e-01, 8.4190862e-03, 3.8701851e-02, 1.0394468e-02,
#         1.0118318e-05, 9.9777657e-01, 2.2884649e-01, 5.9929203e-02,
#         4.2941746e-01, 9.3625695e-04, 3.0452047e-02, 5.7348184e-02],
#        [3.0828720e-01, 9.9999571e-01, 6.9760894e-03, 4.8468687e-04,
#         3.0772386e-12, 3.7423575e-01, 7.6604211e-01, 1.9981435e-02,
#         9.3159211e-01, 7.4577132e-05, 2.7751949e-02, 6.4908637e-04],
#        [3.0803958e-01, 9.9999571e-01, 6.9839028e-03, 4.8518652e-04,
#         3.0793050e-12, 3.7428296e-01, 7.6634258e-01, 1.9990802e-02,
#         9.3168545e-01, 7.4549258e-05, 2.7782798e-02, 6.4983504e-04]],
#       dtype=float32)

# %% [markdown]
# ## Shows the model have no implementation problem, the output doesn't rely on the batch size

# %%
proba_1 = sess.run(output_proba, feed_dict={input_x: dataset.test_set['x'][:3],
                                           input_dev: dataset.test_set['dev'][:3],
                                           is_training: False})
proba_1
# Out:
# array([[9.9249375e-01, 8.4190825e-03, 3.8701873e-02, 1.0394473e-02,
#         1.0118309e-05, 9.9777657e-01, 2.2884654e-01, 5.9929188e-02,
#         4.2941752e-01, 9.3625649e-04, 3.0452035e-02, 5.7348184e-02],
#        [3.0828717e-01, 9.9999571e-01, 6.9760857e-03, 4.8468594e-04,
#         3.0772386e-12, 3.7423581e-01, 7.6604211e-01, 1.9981449e-02,
#         9.3159205e-01, 7.4577067e-05, 2.7751973e-02, 6.4908701e-04],
#        [3.0803975e-01, 9.9999571e-01, 6.9838990e-03, 4.8518681e-04,
#         3.0793050e-12, 3.7428305e-01, 7.6634258e-01, 1.9990802e-02,
#         9.3168545e-01, 7.4549258e-05, 2.7782803e-02, 6.4983539e-04]],
#       dtype=float32)

# %%
# turn real label to one-hot format
real_y = np.eye(12)[dataset.test_set['y']]

# %% [markdown]
# ## Draw ROC for 'GCC0 Link Failure'

# %%
proba_i = proba[:, alarm_list.index('GCC0 Link Failure')]
real_i = real_y[:, alarm_list.index('GCC0 Link Failure')]

pyplot.rcParams["figure.figsize"] = [4,3] # figure size

# calculate auc, false positive rates and etc.
auc, fprs, tprs, thresholds = auc_roc(y_pred=proba_i, y_test=real_i)

# plot roc curve
plot_roc_curve(fprs, tprs, auc, x_axis=0.05)

# %%
## Draw ROC for 'Loss Of Clock'

# %%
proba_i = proba[:, alarm_list.index('Loss Of Clock')]
real_i = real_y[:, alarm_list.index('Loss Of Clock')]

pyplot.rcParams["figure.figsize"] = [4,3] # figure size

# calculate auc, false positive rates and etc.
auc, fprs, tprs, thresholds = auc_roc(y_pred=proba_i, y_test=real_i)

# plot roc curve
plot_roc_curve(fprs, tprs, auc, x_axis=0.05)

# %% [markdown]
# ## Draw ROC and confusion matrix for 'Loss Of Signal'

# %%
proba_i = proba[:, alarm_list.index('Loss Of Signal')]
real_i = real_y[:, alarm_list.index('Loss Of Signal')]


pyplot.rcParams["figure.figsize"] = [4,3] # figure size
# calculate auc, false positive rates and etc.
auc, fprs, tprs, thresholds = auc_roc(y_pred=proba_i, y_test=real_i)

# plot roc curve
plot_roc_curve(fprs, tprs, auc, x_axis=0.05)

# %% [markdown]
# ## Draw ROC for 'OTU Signal Degrade'

# %%
# probability of Excessive Error Ratio
proba_i = proba[:, alarm_list.index('OTU Signal Degrade')]
real_i = real_y[:, alarm_list.index('OTU Signal Degrade')]

pyplot.rcParams["figure.figsize"] = [4,3] # figure size
# calculate auc, false positive rates and etc.
auc, fprs, tprs, thresholds = auc_roc(y_pred=proba_i, y_test=real_i)

# plot roc curve
plot_roc_curve(fprs, tprs, auc, x_axis=0.05)

# %% [markdown]
# ## Two cases that doesn't perform well

# %% [markdown]
# ## Draw ROC for 'Excessive Error Ratio'

# %%
proba_i = proba[:, alarm_list.index('Excessive Error Ratio')]
real_i = real_y[:, alarm_list.index('Excessive Error Ratio')]

pyplot.rcParams["figure.figsize"] = [4,3] # figure size

# calculate auc, false positive rates and etc.
auc, fprs, tprs, thresholds = auc_roc(y_pred=proba_i, y_test=real_i)

# plot roc curve
plot_roc_curve(fprs, tprs, auc, x_axis=0.5)

# %% [markdown]
# ## Draw ROC for 'Loss Of Frame'

# %%
proba_i = proba[:, alarm_list.index('Loss Of Frame')]
real_i = real_y[:, alarm_list.index('Loss Of Frame')]

pyplot.rcParams["figure.figsize"] = [4,3] # figure size

# calculate auc, false positive rates and etc.
auc, fprs, tprs, thresholds = auc_roc(y_pred=proba_i, y_test=real_i)

# plot roc curve
plot_roc_curve(fprs, tprs, auc, x_axis=0.5)

# %% [markdown]
# ## Visualize attention layer

# %%
# output attentions, attn_matrix_input is the input attention and attn_matrix_output is the output attention
attn_matrix_input, attn_matrix_output = sess.run([attention_matrix, attention_matrix_output])

# %%
attn_matrix_input = visualize_input_attention(attn_matrix_input, dev_list, pm_list)

# %%
attn_matrix_input
# Out:
#        BBE-RS   CV-OTU CV-S DROPGAINAVG-OTS DROPGAINMAX-OTS_DROPGAINMIN-OTS_-  \
# AMP         x        x    x          1.0262                          0.999421
# ETH10G      x        x    x               x                                 x
# ETHN        x        x    x               x                                 x
# ETTP        x        x    x               x                                 x
# OC192       x        x    x               x                                 x
# OPTMON      x        x    x               x                                 x
# OSC         x        x    x               x                                 x
# OTM         x  1.14856    x               x                                 x
# OTM2        x  1.01392    x               x                                 x
# OTUTTP      x  1.00062    x               x                                 x
# PTP         x        x    x               x                                 x
#
#        E-CV      E-ES E-INFRAMESERR_E-INFRAMES_/ E-OUTFRAMESERR_E-OUTFRAMES_/  \
# AMP       x         x                          x                            x
# ETH10G    x  0.975674                   0.997918                            x
# ETHN      x    1.0536                   0.848166                     0.980515
# ETTP      x   1.02955                   0.585437                      1.00288
# OC192     x   1.51747                   0.675094                     0.989851
# OPTMON    x         x                          x                            x
# OSC       x         x                          x                            x
# OTM       x         x                          x                            x
# OTM2      x         x                          x                            x
# OTUTTP    x         x                          x                            x
# PTP       x         x                          x                            x
#
#            E-UAS   ES-OTU ES-RS ES-S OCH-OPRAVG OCH-OPRMAX_OCH-OPRMIN_-  \
# AMP            x        x     x    x          x                       x
# ETH10G   1.00522        x     x    x          x                       x
# ETHN    0.951888        x     x    x          x                       x
# ETTP     1.02419        x     x    x          x                       x
# OC192   0.971402        x     x    x          x                       x
# OPTMON         x        x     x    x          x                       x
# OSC            x        x     x    x          x                       x
# OTM            x  1.00697     x    x   0.991946                0.953302
# OTM2           x  1.10276     x    x          x                       x
# OTUTTP         x  1.06703     x    x          x                       x
# PTP            x        x     x    x    1.17157                0.958081
#
#        OCH-SPANLOSSAVG OCH-SPANLOSSMAX_OCH-SPANLOSSMIN_- OPINAVG-OTS  \
# AMP                  x                                 x    0.800571
# ETH10G               x                                 x           x
# ETHN                 x                                 x           x
# ETTP                 x                                 x           x
# OC192                x                                 x           x
# OPTMON               x                                 x           x
# OSC            1.03046                          0.469445           x
# OTM                  x                                 x           x
# OTM2                 x                                 x           x
# OTUTTP               x                                 x           x
# PTP                  x                                 x           x
#
#        OPINMAX-OTS_OPINMIN-OTS_- OPOUTAVG-OTS OPOUTAVG-OTS_OPINAVG-OTS_-  \
# AMP                     0.646144       0.7406                   0.748603
# ETH10G                         x            x                          x
# ETHN                           x            x                          x
# ETTP                           x            x                          x
# OC192                          x            x                          x
# OPTMON                         x            x                          x
# OSC                            x            x                          x
# OTM                            x            x                          x
# OTM2                           x            x                          x
# OTUTTP                         x            x                          x
# PTP                            x            x                          x
#
#        OPOUTMAX-OTS_OPOUTMIN-OTS_- OPRAVG-OCH OPRAVG-OTS  \
# AMP                       0.489353          x          x
# ETH10G                           x          x          x
# ETHN                             x          x          x
# ETTP                             x          x          x
# OC192                            x          x          x
# OPTMON                           x          x   0.997872
# OSC                              x          x          x
# OTM                              x   0.835254          x
# OTM2                             x          x          x
# OTUTTP                           x          x          x
# PTP                              x    1.04809          x
#
#        OPRMAX-OCH_OPRMIN-OCH_- OPRMAX-OTS_OPRMIN-OTS_- OPTAVG-OCH OPTAVG-OTS  \
# AMP                          x                       x          x          x
# ETH10G                       x                       x          x          x
# ETHN                         x                       x          x          x
# ETTP                         x                       x          x          x
# OC192                        x                       x          x          x
# OPTMON                       x                0.915578          x    1.11458
# OSC                          x                       x          x          x
# OTM                   0.961238                       x          x          x
# OTM2                         x                       x          x          x
# OTUTTP                       x                       x          x          x
# PTP                    1.04545                       x          x          x
#
#        OPTMAX-OCH_OPTMIN-OCH_- OPTMAX-OTS_OPTMIN-OTS_- ORLAVG-OTS ORLMIN-OTS  \
# AMP                          x                       x   0.719766   0.621451
# ETH10G                       x                       x          x          x
# ETHN                         x                       x          x          x
# ETTP                         x                       x          x          x
# OC192                        x                       x          x          x
# OPTMON                       x                0.932623          x          x
# OSC                          x                       x          x          x
# OTM                          x                       x          x          x
# OTM2                         x                       x          x          x
# OTUTTP                       x                       x          x          x
# PTP                          x                       x          x          x
#
#        OTU-CV    OTU-ES  OTU-QAVG OTU-QSTDEV    PCS-CV    PCS-ES   PCS-UAS  \
# AMP         x         x         x          x         x         x         x
# ETH10G      x         x         x          x         x  0.997469  0.992187
# ETHN        x         x         x          x   1.29218   1.34603  0.927396
# ETTP        x         x         x          x  0.704907  0.976359  0.910078
# OC192       x         x         x          x  0.999254   1.47061   1.10785
# OPTMON      x         x         x          x         x         x         x
# OSC         x         x         x          x         x         x         x
# OTM         x   1.16291  0.933635    1.11235         x         x         x
# OTM2        x  0.987863         x          x         x         x         x
# OTUTTP      x   1.05011   1.10493    1.10249         x         x         x
# PTP         x         x         x          x         x         x         x
#
#        QAVG-OTU QSTDEV-OTU RS-BBE RS-ES S-CV     S-ES
# AMP           x          x      x     x    x        x
# ETH10G        x          x      x     x    x        x
# ETHN          x          x      x     x    x  1.00784
# ETTP          x          x      x     x    x  1.00565
# OC192         x          x      x     x    x  1.00158
# OPTMON        x          x      x     x    x        x
# OSC           x          x      x     x    x        x
# OTM     1.07132   0.957545      x     x    x        x
# OTM2          x          x      x     x    x        x
# OTUTTP  1.03997    1.00255      x     x    x        x
# PTP           x          x      x     x    x        x

# %%
attn_matrix_output = visualize_output_attention(attn_matrix_output, dev_list, alarm_list)

# %%
attn_matrix_output.round(3)
# Out:
#         Excessive Error Ratio  Frequency Out Of Range  GCC0 Link Failure  \
# AMP                    -0.033                  -0.002             -0.004
# ETH10G                  0.000                   0.000              0.000
# ETHN                   -0.296                  -0.018             -0.652
# ETTP                   -0.245                  -0.347             -0.610
# OC192                   0.095                   0.153             -0.628
# OPTMON                 -0.222                  -0.401             -0.509
# OSC                    -0.027                  -0.004             -0.011
# OTM                    -0.479                  -0.470              0.819
# OTM2                   -0.701                  -0.719             -0.060
# OTUTTP                 -0.150                  -0.189              0.443
# PTP                    -0.016                  -0.001             -0.013
#
#         Gauge Threshold Crossing Alert Summary  Link Down  Local Fault  \
# AMP                                      0.264     -0.004       -0.017
# ETH10G                                   0.000      0.000        0.000
# ETHN                                    -0.523      0.183        0.050
# ETTP                                    -0.409     -0.016       -0.092
# OC192                                   -0.415     -0.146        0.028
# OPTMON                                   0.067     -0.039       -0.456
# OSC                                     -0.049     -0.004       -0.057
# OTM                                     -0.141     -0.046       -0.526
# OTM2                                    -0.640     -0.078       -0.622
# OTUTTP                                  -0.164     -0.010       -0.237
# PTP                                     -0.138     -0.002       -0.134
#
#         Loss Of Clock  Loss Of Frame  Loss Of Signal  OSC OSPF Adjacency Loss  \
# AMP            -0.008         -0.072          -0.054                   -0.036
# ETH10G          0.000          0.000           0.000                    0.000
# ETHN           -0.097          0.010           0.232                   -0.155
# ETTP            0.455         -0.029          -0.015                   -0.082
# OC192          -0.010         -0.000          -0.330                   -0.149
# OPTMON         -0.500         -0.458          -0.000                   -0.234
# OSC            -0.007         -0.013          -0.035                    0.233
# OTM             0.919          0.113          -0.159                   -0.086
# OTM2           -0.665          0.087           0.317                   -0.510
# OTUTTP          0.461         -0.328          -0.295                   -0.061
# PTP            -0.020         -0.024           0.723                   -0.035
#
#         OTU Signal Degrade  Rx Power Out Of Range
# AMP                 -0.001                 -0.001
# ETH10G               0.000                  0.000
# ETHN                -0.730                 -0.000
# ETTP                -0.627                  0.044
# OC192               -0.595                 -0.411
# OPTMON              -0.524                 -0.330
# OSC                 -0.002                 -0.008
# OTM                 -0.711                  0.125
# OTM2                 0.613                  0.010
# OTUTTP              -0.292                 -0.347
# PTP                 -0.002                 -0.025
